# %% [markdown]
# # 🐼 Pandas - Class 7: Merging, Joining & Concatenation
# Welcome to **Class 7** of our Pandas series. Today we’ll learn how to combine multiple DataFrames using different techniques.

# %% [markdown]
# ## 1. Using `concat()` for Stacking Data
# - `pd.concat()` combines DataFrames vertically (rows) or horizontally (columns).
# - Use `axis=0` for vertical stacking (default), `axis=1` for horizontal.
# - `ignore_index=True` can reset the index after concatenation.

# %%
# Dataset 1: Product details
import pandas as pd

# Dataset 1
df1 = pd.DataFrame({
    "ID": [1, 2, 3],
    "Name": ["Saurabh", "Amit", "Raj"],
    "Age": [22, 25, 28],
    "Department": ["IT", "HR", "Finance"],
    "Salary": [40000, 30000, 50000]
})

# Dataset 2
df2 = pd.DataFrame({
    "ID": [4, 5, 6],
    "Name": ["Gaurav", "Neha", "Pooja"],
    "Age": [26, 24, 27],
    "Department": ["IT", "HR", "Finance"],
    "Salary": [45000, 32000, 48000]
})

# Dataset 3
df3 = pd.DataFrame({
    "ID": [1, 2, 5],  # matching with df1
    "ProductName": ["Laptop", "Phone", "Chair"],
    "Price": [60000, 30000, 5000],
    "Category": ["Electronics", "Electronics", "Furniture"]
})

all_employee = pd.concat([df1,df2],axis=0,ignore_index=True)
print(all_employee)
# Out:
#    ID     Name  Age Department  Salary
# 0   1  Saurabh   22         IT   40000
# 1   2     Amit   25         HR   30000
# 2   3      Raj   28    Finance   50000
# 3   4   Gaurav   26         IT   45000
# 4   5     Neha   24         HR   32000
# 5   6    Pooja   27    Finance   48000

# %% [markdown]
# ## 2. Using `merge()` for SQL-Style Joins
# - `merge()` is similar to SQL joins.
# - Specify `on` or `left_on`/`right_on` to choose key columns.
# - Join types: `inner` (default), `left`, `right`, `outer`.

# %%
result = pd.merge(all_employee,df3, on="ID")
pd.merge(df1,df3 ,on="ID" , how = "outer")
# Out:
#    ID     Name   Age Department   Salary ProductName    Price     Category
# 0   1  Saurabh  22.0         IT  40000.0      Laptop  60000.0  Electronics
# 1   2     Amit  25.0         HR  30000.0       Phone  30000.0  Electronics
# 2   3      Raj  28.0    Finance  50000.0         NaN      NaN          NaN
# 3   5      NaN   NaN        NaN      NaN       Chair   5000.0    Furniture

# %% [markdown]
# ## 3. Using `join()` with Index Alignment
# - `join()` joins DataFrames on their index or on a key column.
# - By default, joins on index; can specify `on='col'`.
# - Useful for adding columns to an existing DataFrame.

# %%
result = df1.set_index("ID").join(df3.set_index("ID"))
print(result)
# Out:
#        Name  Age Department  Salary ProductName    Price     Category
# ID
# 1   Saurabh   22         IT   40000      Laptop  60000.0  Electronics
# 2      Amit   25         HR   30000       Phone  30000.0  Electronics
# 3       Raj   28    Finance   50000         NaN      NaN          NaN

# %% [markdown]
# ## 4. Practical Examples
# - Combine sales and revenue data to see performance.
# - Merge students with marks to link records.
# - Practice with realistic datasets to understand alignment and missing data handling.

# %% [markdown]
# ## Mini Practice
# 1. Create three DataFrames: Products, Sales, and Revenue.
# 2. Concatenate them vertically and horizontally.
# 3. Merge Sales and Revenue using different join types.
# 4. Join Products with Sales based on index or a key.
# 5. Analyze missing values after joins.

# %%
# 1. Create three DataFrames: Products, Sales, and Revenue
import pandas as pd

products = pd.DataFrame({
    "ProductID": [101, 102, 103],
    "ProductName": ["Laptop", "Phone", "Chair"],
    "Category": ["Electronics", "Electronics", "Furniture"]
})

sales = pd.DataFrame({
    "ProductID": [101, 102, 103,104],
    "QuantitySold": [5, 10, 7,8],
    "City": ["Pune", "Mumbai", "Delhi","Rewa"]
})

revenue = pd.DataFrame({
    "ProductID": [101, 102, 103],
    "Revenue": [300000, 300000, 35000]
})

# 2. Concatenate them vertically and horizontally
# Write your code here
pd.concat([products,sales],axis=1)

# 3. Merge Sales and Revenue using different join types (inner, left, right, outer)
# Write your code here
pd.merge(sales,revenue , on="ProductID", how='right')
# 4. Join Products with Sales based on index or a key
# Write your code here

result = sales.set_index("ProductID").join(products.set_index("ProductID"))
print(result)

# 5. Analyze missing values after joins
# Use isna(), info(), or describe() to explore gaps
# Write your code here
result.isna()
result.info()
result.describe()
# Out:
#            QuantitySold    City ProductName     Category
# ProductID
# 101                   5    Pune      Laptop  Electronics
# 102                  10  Mumbai       Phone  Electronics
# 103                   7   Delhi       Chair    Furniture
# 104                   8    Rewa         NaN          NaN
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 101 to 104
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   QuantitySold  4 non-null      int64
#  1   City          4 non-null      object
#  2   ProductName   3 non-null      object
#  3   Category      3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 160.0+ bytes
#        QuantitySold
# count      4.000000
# mean       7.500000
# std        2.081666
# min        5.000000
# 25%        6.500000
# 50%        7.500000
# 75%        8.500000
# max       10.000000

# %% [markdown]
# ---
# ## Summary
# - Used `concat()` for stacking data vertically and horizontally.
# - Performed SQL-style joins with `merge()`.
# - Applied `join()` with index alignment.
# - Explored practical use-cases like sales vs revenue, students vs marks.
